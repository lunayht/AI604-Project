# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
import math

# %% [markdown]
# # Configure hyperparameters

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 16
num_epochs = 500
image_size = (460,700)  # We'll resize input images to this size
patch_size =(64,64)  # Size of the patches to be extract from the input images
num_patches = math.ceil((image_size[0] / patch_size[0]))* math.ceil((image_size[1] / patch_size[1]))
projection_dim = 64
num_heads = 8 # 4, 8 good
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8# 8, 6
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier
num_classes = 10
input_shape = (460,700, 3)

# %%
num_patches
# Out:
# 88

# %% [markdown]
# # Loading the data

# %%
train_examples =np.load('feature40x.npy')
train_labels = np.load('multilabels.npy')
test_examples = np.load('testfeature40x.npy')
test_labels = np.load('testmultilabels.npy')

# %%
# y_train = np.load('trainsparetype.npy')
# y_test = np.load('testsparetype.npy')
# y_train = np.load('trainsparsecls.npy')
# y_test = np.load('testsparsecls.npy')

# %%
# train_dataset = tf.data.Dataset.from_tensor_slices((train_examples, train_labels))
# test_dataset = tf.data.Dataset.from_tensor_slices((test_examples, test_labels))

# %%
x_train = train_examples
y_train = train_labels
x_test = test_examples
y_test = test_labels

# %%
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (1396, 460, 700, 3) - y_train shape: (1396, 10)
# x_test shape: (599, 460, 700, 3) - y_test shape: (599, 10)

# %%
# np.std(x_train/255.0, axis=(0,1,2))

# %% [markdown]
# # data augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.Normalization(),
        layers.experimental.preprocessing.Resizing(image_size[0], image_size[1]),
        layers.experimental.preprocessing.RandomFlip("horizontal"),
#         layers.experimental.preprocessing.RandomFlip("vertical"),
        layers.experimental.preprocessing.RandomRotation(factor=0.02),
        layers.experimental.preprocessing.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
# 700/128

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size[0], self.patch_size[1], 1],
            strides=[1, self.patch_size[0], self.patch_size[1], 1],
            rates=[1, 1, 1, 1],
            padding="SAME",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
import matplotlib.pyplot as plt
import math

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size[0], image_size[1])
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size[0]} X {image_size[1]}")
print(f"Patch size: {patch_size[0]} X {patch_size[1]}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

# n = math.ceil(np.sqrt(patches.shape[1]))
n=math.ceil((image_size[1] / patch_size[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size[0], patch_size[1], 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 460 X 700
# Patch size: 64 X 64
# Patches per image: 88
# Elements per patch: 12288

# %%
patches.shape[1]
# Out:
# 88

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
# def mlp(x, hidden_units, dropout_rate):
#     for units in hidden_units:
#         x = layers.Dense(units, activation=tf.nn.gelu)(x)
#         x = layers.Dropout(dropout_rate)(x)
#     return x

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.

    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.BinaryCrossentropy(from_logits=True),
#         loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.BinaryAccuracy(name="binary_accuracy"),
#             keras.metrics.CategoricalAccuracy(name="accuracy"),
#             keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),'sparse_categorical_accuracy
        ],
    )

    checkpoint_filepath = "./tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_binary_accuracy",
#         monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,

        validation_split=0.1,
        shuffle=True,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    predictions = model.predict(x_test)


    return history, predictions


vit_classifier = create_vit_classifier()
history, preds = run_experiment(vit_classifier)
# Out:
# Epoch 1/500
# 79/79 [==============================] - 8s 41ms/step - loss: 0.9759 - binary_accuracy: 0.7982 - val_loss: 0.4109 - val_binary_accuracy: 0.8521
# Epoch 2/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.4609 - binary_accuracy: 0.8442 - val_loss: 0.3129 - val_binary_accuracy: 0.8714
# Epoch 3/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.3617 - binary_accuracy: 0.8648 - val_loss: 0.2833 - val_binary_accuracy: 0.8821
# Epoch 4/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.3474 - binary_accuracy: 0.8663 - val_loss: 0.2837 - val_binary_accuracy: 0.8864
# Epoch 5/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.3280 - binary_accuracy: 0.8727 - val_loss: 0.2667 - val_binary_accuracy: 0.8936
# Epoch 6/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.3139 - binary_accuracy: 0.8815 - val_loss: 0.2581 - val_binary_accuracy: 0.8893
# Epoch 7/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.2929 - binary_accuracy: 0.8854 - val_loss: 0.2535 - val_binary_accuracy: 0.8914
# Epoch 8/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.2788 - binary_accuracy: 0.8906 - val_loss: 0.2746 - val_binary_accuracy: 0.8786
# Epoch 9/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.2770 - binary_accuracy: 0.8915 - val_loss: 0.2689 - val_binary_accuracy: 0.8986
# Epoch 10/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.2778 - binary_accuracy: 0.8913 - val_loss: 0.2343 - val_binary_accuracy: 0.8936
# Epoch 11/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.2526 - binary_accuracy: 0.9012 - val_loss: 0.2489 - val_binary_accuracy: 0.9050
# Epoch 12/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.2474 - binary_accuracy: 0.8997 - val_loss: 0.2066 - val_binary_accuracy: 0.9071
# Epoch 13/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.2467 - binary_accuracy: 0.8990 - val_loss: 0.2285 - val_binary_accuracy: 0.9100
# Epoch 14/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.2308 - binary_accuracy: 0.9076 - val_loss: 0.2274 - val_binary_accuracy: 0.9064
# Epoch 15/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.2379 - binary_accuracy: 0.9001 - val_loss: 0.2079 - val_binary_accuracy: 0.9057
# Epoch 16/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.2180 - binary_accuracy: 0.9095 - val_loss: 0.1937 - val_binary_accuracy: 0.9221
# Epoch 17/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.2093 - binary_accuracy: 0.9146 - val_loss: 0.2032 - val_binary_accuracy: 0.9129
# Epoch 18/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.1954 - binary_accuracy: 0.9194 - val_loss: 0.1798 - val_binary_accuracy: 0.9200
# Epoch 19/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1815 - binary_accuracy: 0.9256 - val_loss: 0.1663 - val_binary_accuracy: 0.9321
# Epoch 20/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1786 - binary_accuracy: 0.9291 - val_loss: 0.1837 - val_binary_accuracy: 0.9207
# Epoch 21/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1757 - binary_accuracy: 0.9245 - val_loss: 0.1560 - val_binary_accuracy: 0.9221
# Epoch 22/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1674 - binary_accuracy: 0.9286 - val_loss: 0.1583 - val_binary_accuracy: 0.9293
# Epoch 23/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1678 - binary_accuracy: 0.9353 - val_loss: 0.1659 - val_binary_accuracy: 0.9307
# Epoch 24/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1868 - binary_accuracy: 0.9252 - val_loss: 0.1423 - val_binary_accuracy: 0.9329
# Epoch 25/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1543 - binary_accuracy: 0.9367 - val_loss: 0.1665 - val_binary_accuracy: 0.9221
# Epoch 26/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.1438 - binary_accuracy: 0.9383 - val_loss: 0.1475 - val_binary_accuracy: 0.9371
# Epoch 27/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1387 - binary_accuracy: 0.9379 - val_loss: 0.1503 - val_binary_accuracy: 0.9286
# Epoch 28/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.1622 - binary_accuracy: 0.9355 - val_loss: 0.1347 - val_binary_accuracy: 0.9393
# Epoch 29/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1354 - binary_accuracy: 0.9411 - val_loss: 0.1063 - val_binary_accuracy: 0.9493
# Epoch 30/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1288 - binary_accuracy: 0.9476 - val_loss: 0.1364 - val_binary_accuracy: 0.9371
# Epoch 31/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.1251 - binary_accuracy: 0.9492 - val_loss: 0.1169 - val_binary_accuracy: 0.9536
# Epoch 32/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1331 - binary_accuracy: 0.9446 - val_loss: 0.1308 - val_binary_accuracy: 0.9450
# Epoch 33/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.1457 - binary_accuracy: 0.9407 - val_loss: 0.1571 - val_binary_accuracy: 0.9314
# Epoch 34/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.1358 - binary_accuracy: 0.9407 - val_loss: 0.1350 - val_binary_accuracy: 0.9443
# Epoch 35/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1088 - binary_accuracy: 0.9571 - val_loss: 0.1167 - val_binary_accuracy: 0.9479
# Epoch 36/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.1114 - binary_accuracy: 0.9558 - val_loss: 0.1059 - val_binary_accuracy: 0.9536
# Epoch 37/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1242 - binary_accuracy: 0.9497 - val_loss: 0.1059 - val_binary_accuracy: 0.9543
# Epoch 38/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1105 - binary_accuracy: 0.9553 - val_loss: 0.1192 - val_binary_accuracy: 0.9521
# Epoch 39/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0938 - binary_accuracy: 0.9626 - val_loss: 0.1225 - val_binary_accuracy: 0.9457
# Epoch 40/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1044 - binary_accuracy: 0.9563 - val_loss: 0.1151 - val_binary_accuracy: 0.9521
# Epoch 41/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0903 - binary_accuracy: 0.9599 - val_loss: 0.1335 - val_binary_accuracy: 0.9464
# Epoch 42/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1047 - binary_accuracy: 0.9587 - val_loss: 0.1611 - val_binary_accuracy: 0.9421
# Epoch 43/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.1099 - binary_accuracy: 0.9585 - val_loss: 0.1051 - val_binary_accuracy: 0.9607
# Epoch 44/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.1025 - binary_accuracy: 0.9583 - val_loss: 0.1180 - val_binary_accuracy: 0.9514
# Epoch 45/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0895 - binary_accuracy: 0.9640 - val_loss: 0.1398 - val_binary_accuracy: 0.9529
# Epoch 46/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0892 - binary_accuracy: 0.9651 - val_loss: 0.1297 - val_binary_accuracy: 0.9486
# Epoch 47/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0968 - binary_accuracy: 0.9586 - val_loss: 0.1062 - val_binary_accuracy: 0.9536
# Epoch 48/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0816 - binary_accuracy: 0.9686 - val_loss: 0.1201 - val_binary_accuracy: 0.9557
# Epoch 49/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.1009 - binary_accuracy: 0.9612 - val_loss: 0.1117 - val_binary_accuracy: 0.9579
# Epoch 50/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.1135 - binary_accuracy: 0.9606 - val_loss: 0.1225 - val_binary_accuracy: 0.9450
# Epoch 51/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0839 - binary_accuracy: 0.9636 - val_loss: 0.1077 - val_binary_accuracy: 0.9621
# Epoch 52/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0728 - binary_accuracy: 0.9707 - val_loss: 0.1181 - val_binary_accuracy: 0.9536
# Epoch 53/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0802 - binary_accuracy: 0.9707 - val_loss: 0.1273 - val_binary_accuracy: 0.9571
# Epoch 54/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0868 - binary_accuracy: 0.9677 - val_loss: 0.1111 - val_binary_accuracy: 0.9564
# Epoch 55/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0560 - binary_accuracy: 0.9768 - val_loss: 0.1212 - val_binary_accuracy: 0.9471
# Epoch 56/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0713 - binary_accuracy: 0.9707 - val_loss: 0.1213 - val_binary_accuracy: 0.9564
# Epoch 57/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0686 - binary_accuracy: 0.9743 - val_loss: 0.1074 - val_binary_accuracy: 0.9650
# Epoch 58/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0683 - binary_accuracy: 0.9743 - val_loss: 0.1275 - val_binary_accuracy: 0.9529
# Epoch 59/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0572 - binary_accuracy: 0.9773 - val_loss: 0.1093 - val_binary_accuracy: 0.9614
# Epoch 60/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0735 - binary_accuracy: 0.9698 - val_loss: 0.1057 - val_binary_accuracy: 0.9571
# Epoch 61/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0674 - binary_accuracy: 0.9758 - val_loss: 0.1063 - val_binary_accuracy: 0.9607
# Epoch 62/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0804 - binary_accuracy: 0.9694 - val_loss: 0.0908 - val_binary_accuracy: 0.9614
# Epoch 63/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0646 - binary_accuracy: 0.9748 - val_loss: 0.1002 - val_binary_accuracy: 0.9643
# Epoch 64/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0611 - binary_accuracy: 0.9745 - val_loss: 0.1071 - val_binary_accuracy: 0.9586
# Epoch 65/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0669 - binary_accuracy: 0.9724 - val_loss: 0.1021 - val_binary_accuracy: 0.9643
# Epoch 66/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0613 - binary_accuracy: 0.9761 - val_loss: 0.1254 - val_binary_accuracy: 0.9500
# Epoch 67/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0561 - binary_accuracy: 0.9811 - val_loss: 0.0800 - val_binary_accuracy: 0.9714
# Epoch 68/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0500 - binary_accuracy: 0.9800 - val_loss: 0.1298 - val_binary_accuracy: 0.9607
# Epoch 69/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0500 - binary_accuracy: 0.9815 - val_loss: 0.1469 - val_binary_accuracy: 0.9593
# Epoch 70/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0389 - binary_accuracy: 0.9843 - val_loss: 0.1630 - val_binary_accuracy: 0.9500
# Epoch 71/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0497 - binary_accuracy: 0.9803 - val_loss: 0.1056 - val_binary_accuracy: 0.9707
# Epoch 72/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0498 - binary_accuracy: 0.9807 - val_loss: 0.1188 - val_binary_accuracy: 0.9593
# Epoch 73/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0431 - binary_accuracy: 0.9838 - val_loss: 0.1802 - val_binary_accuracy: 0.9421
# Epoch 74/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0723 - binary_accuracy: 0.9738 - val_loss: 0.1106 - val_binary_accuracy: 0.9600
# Epoch 75/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0680 - binary_accuracy: 0.9734 - val_loss: 0.1258 - val_binary_accuracy: 0.9607
# Epoch 76/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0636 - binary_accuracy: 0.9777 - val_loss: 0.1011 - val_binary_accuracy: 0.9721
# Epoch 77/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0448 - binary_accuracy: 0.9813 - val_loss: 0.1045 - val_binary_accuracy: 0.9700
# Epoch 78/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0450 - binary_accuracy: 0.9820 - val_loss: 0.1051 - val_binary_accuracy: 0.9671
# Epoch 79/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0559 - binary_accuracy: 0.9796 - val_loss: 0.0996 - val_binary_accuracy: 0.9679
# Epoch 80/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0350 - binary_accuracy: 0.9857 - val_loss: 0.1209 - val_binary_accuracy: 0.9679
# Epoch 81/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0417 - binary_accuracy: 0.9860 - val_loss: 0.1338 - val_binary_accuracy: 0.9614
# Epoch 82/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0456 - binary_accuracy: 0.9834 - val_loss: 0.1184 - val_binary_accuracy: 0.9543
# Epoch 83/500
# 79/79 [==============================] - ETA: 0s - loss: 0.0462 - binary_accuracy: 0.982 - 3s 33ms/step - loss: 0.0463 - binary_accuracy: 0.9827 - val_loss: 0.1318 - val_binary_accuracy: 0.9521
# Epoch 84/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0472 - binary_accuracy: 0.9808 - val_loss: 0.1162 - val_binary_accuracy: 0.9636
# Epoch 85/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0398 - binary_accuracy: 0.9836 - val_loss: 0.1662 - val_binary_accuracy: 0.9557
# Epoch 86/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0465 - binary_accuracy: 0.9821 - val_loss: 0.0888 - val_binary_accuracy: 0.9707
# Epoch 87/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0472 - binary_accuracy: 0.9820 - val_loss: 0.1115 - val_binary_accuracy: 0.9600
# Epoch 88/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0461 - binary_accuracy: 0.9824 - val_loss: 0.1616 - val_binary_accuracy: 0.9529
# Epoch 89/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0517 - binary_accuracy: 0.9820 - val_loss: 0.1141 - val_binary_accuracy: 0.9614
# Epoch 90/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0397 - binary_accuracy: 0.9827 - val_loss: 0.1507 - val_binary_accuracy: 0.9536
# Epoch 91/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0473 - binary_accuracy: 0.9832 - val_loss: 0.0973 - val_binary_accuracy: 0.9671
# Epoch 92/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0480 - binary_accuracy: 0.9817 - val_loss: 0.1055 - val_binary_accuracy: 0.9693
# Epoch 93/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0503 - binary_accuracy: 0.9813 - val_loss: 0.1119 - val_binary_accuracy: 0.9579
# Epoch 94/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0604 - binary_accuracy: 0.9774 - val_loss: 0.1228 - val_binary_accuracy: 0.9679
# Epoch 95/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0587 - binary_accuracy: 0.9796 - val_loss: 0.1090 - val_binary_accuracy: 0.9657
# Epoch 96/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0452 - binary_accuracy: 0.9822 - val_loss: 0.1426 - val_binary_accuracy: 0.9579
# Epoch 97/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0484 - binary_accuracy: 0.9830 - val_loss: 0.1184 - val_binary_accuracy: 0.9671
# Epoch 98/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0319 - binary_accuracy: 0.9873 - val_loss: 0.1707 - val_binary_accuracy: 0.9600
# Epoch 99/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0343 - binary_accuracy: 0.9870 - val_loss: 0.1251 - val_binary_accuracy: 0.9593
# Epoch 100/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0398 - binary_accuracy: 0.9855 - val_loss: 0.1329 - val_binary_accuracy: 0.9507
# Epoch 101/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0447 - binary_accuracy: 0.9821 - val_loss: 0.1161 - val_binary_accuracy: 0.9636
# Epoch 102/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0300 - binary_accuracy: 0.9875 - val_loss: 0.1291 - val_binary_accuracy: 0.9621
# Epoch 103/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0340 - binary_accuracy: 0.9882 - val_loss: 0.1299 - val_binary_accuracy: 0.9593
# Epoch 104/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0457 - binary_accuracy: 0.9813 - val_loss: 0.1215 - val_binary_accuracy: 0.9571
# Epoch 105/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0416 - binary_accuracy: 0.9857 - val_loss: 0.0808 - val_binary_accuracy: 0.9771
# Epoch 106/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0331 - binary_accuracy: 0.9852 - val_loss: 0.0937 - val_binary_accuracy: 0.9743
# Epoch 107/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0310 - binary_accuracy: 0.9871 - val_loss: 0.1118 - val_binary_accuracy: 0.9607
# Epoch 108/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0452 - binary_accuracy: 0.9815 - val_loss: 0.1280 - val_binary_accuracy: 0.9700
# Epoch 109/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0432 - binary_accuracy: 0.9860 - val_loss: 0.1150 - val_binary_accuracy: 0.9629
# Epoch 110/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0411 - binary_accuracy: 0.9834 - val_loss: 0.1154 - val_binary_accuracy: 0.9714
# Epoch 111/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0398 - binary_accuracy: 0.9857 - val_loss: 0.1251 - val_binary_accuracy: 0.9643
# Epoch 112/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0392 - binary_accuracy: 0.9869 - val_loss: 0.1123 - val_binary_accuracy: 0.9636
# Epoch 113/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0484 - binary_accuracy: 0.9834 - val_loss: 0.1161 - val_binary_accuracy: 0.9679
# Epoch 114/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0368 - binary_accuracy: 0.9842 - val_loss: 0.1072 - val_binary_accuracy: 0.9714
# Epoch 115/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0394 - binary_accuracy: 0.9842 - val_loss: 0.1154 - val_binary_accuracy: 0.9657
# Epoch 116/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0247 - binary_accuracy: 0.9904 - val_loss: 0.1245 - val_binary_accuracy: 0.9700
# Epoch 117/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0511 - binary_accuracy: 0.9828 - val_loss: 0.1317 - val_binary_accuracy: 0.9629
# Epoch 118/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0447 - binary_accuracy: 0.9842 - val_loss: 0.1573 - val_binary_accuracy: 0.9607
# Epoch 119/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0335 - binary_accuracy: 0.9883 - val_loss: 0.1065 - val_binary_accuracy: 0.9650
# Epoch 120/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0315 - binary_accuracy: 0.9874 - val_loss: 0.0938 - val_binary_accuracy: 0.9736
# Epoch 121/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0372 - binary_accuracy: 0.9851 - val_loss: 0.1122 - val_binary_accuracy: 0.9671
# Epoch 122/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0401 - binary_accuracy: 0.9867 - val_loss: 0.1074 - val_binary_accuracy: 0.9721
# Epoch 123/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0265 - binary_accuracy: 0.9893 - val_loss: 0.1416 - val_binary_accuracy: 0.9643
# Epoch 124/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0365 - binary_accuracy: 0.9863 - val_loss: 0.1325 - val_binary_accuracy: 0.9621
# Epoch 125/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0297 - binary_accuracy: 0.9873 - val_loss: 0.1190 - val_binary_accuracy: 0.9671
# Epoch 126/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0266 - binary_accuracy: 0.9878 - val_loss: 0.1276 - val_binary_accuracy: 0.9629
# Epoch 127/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0536 - binary_accuracy: 0.9812 - val_loss: 0.1226 - val_binary_accuracy: 0.9600
# Epoch 128/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0441 - binary_accuracy: 0.9832 - val_loss: 0.1032 - val_binary_accuracy: 0.9743
# Epoch 129/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0243 - binary_accuracy: 0.9904 - val_loss: 0.1237 - val_binary_accuracy: 0.9671
# Epoch 130/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0235 - binary_accuracy: 0.9905 - val_loss: 0.0941 - val_binary_accuracy: 0.9729
# Epoch 131/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0428 - binary_accuracy: 0.9857 - val_loss: 0.1111 - val_binary_accuracy: 0.9643
# Epoch 132/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0458 - binary_accuracy: 0.9822 - val_loss: 0.1357 - val_binary_accuracy: 0.9621
# Epoch 133/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0383 - binary_accuracy: 0.9862 - val_loss: 0.1105 - val_binary_accuracy: 0.9671
# Epoch 134/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0289 - binary_accuracy: 0.9875 - val_loss: 0.1169 - val_binary_accuracy: 0.9693
# Epoch 135/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0277 - binary_accuracy: 0.9909 - val_loss: 0.1558 - val_binary_accuracy: 0.9529
# Epoch 136/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0333 - binary_accuracy: 0.9864 - val_loss: 0.1354 - val_binary_accuracy: 0.9593
# Epoch 137/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0532 - binary_accuracy: 0.9828 - val_loss: 0.1084 - val_binary_accuracy: 0.9686
# Epoch 138/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0482 - binary_accuracy: 0.9825 - val_loss: 0.1079 - val_binary_accuracy: 0.9707
# Epoch 139/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0190 - binary_accuracy: 0.9919 - val_loss: 0.1508 - val_binary_accuracy: 0.9607
# Epoch 140/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0344 - binary_accuracy: 0.9874 - val_loss: 0.1293 - val_binary_accuracy: 0.9586
# Epoch 141/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0294 - binary_accuracy: 0.9881 - val_loss: 0.0990 - val_binary_accuracy: 0.9714
# Epoch 142/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0291 - binary_accuracy: 0.9886 - val_loss: 0.0947 - val_binary_accuracy: 0.9700
# Epoch 143/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0152 - binary_accuracy: 0.9938 - val_loss: 0.1052 - val_binary_accuracy: 0.9693
# Epoch 144/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0228 - binary_accuracy: 0.9899 - val_loss: 0.1163 - val_binary_accuracy: 0.9643
# Epoch 145/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0210 - binary_accuracy: 0.9902 - val_loss: 0.1016 - val_binary_accuracy: 0.9714
# Epoch 146/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0318 - binary_accuracy: 0.9898 - val_loss: 0.1235 - val_binary_accuracy: 0.9700
# Epoch 147/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0358 - binary_accuracy: 0.9866 - val_loss: 0.1374 - val_binary_accuracy: 0.9693
# Epoch 148/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0341 - binary_accuracy: 0.9869 - val_loss: 0.1315 - val_binary_accuracy: 0.9671
# Epoch 149/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0205 - binary_accuracy: 0.9930 - val_loss: 0.0772 - val_binary_accuracy: 0.9793
# Epoch 150/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0262 - binary_accuracy: 0.9892 - val_loss: 0.1089 - val_binary_accuracy: 0.9729
# Epoch 151/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0411 - binary_accuracy: 0.9856 - val_loss: 0.1202 - val_binary_accuracy: 0.9643
# Epoch 152/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0245 - binary_accuracy: 0.9898 - val_loss: 0.1247 - val_binary_accuracy: 0.9643
# Epoch 153/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0418 - binary_accuracy: 0.9859 - val_loss: 0.1327 - val_binary_accuracy: 0.9621
# Epoch 154/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0406 - binary_accuracy: 0.9839 - val_loss: 0.1483 - val_binary_accuracy: 0.9564
# Epoch 155/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0334 - binary_accuracy: 0.9872 - val_loss: 0.1368 - val_binary_accuracy: 0.9614
# Epoch 156/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0359 - binary_accuracy: 0.9872 - val_loss: 0.1362 - val_binary_accuracy: 0.9671
# Epoch 157/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0251 - binary_accuracy: 0.9907 - val_loss: 0.0978 - val_binary_accuracy: 0.9671
# Epoch 158/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0419 - binary_accuracy: 0.9833 - val_loss: 0.1353 - val_binary_accuracy: 0.9557
# Epoch 159/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0262 - binary_accuracy: 0.9888 - val_loss: 0.1398 - val_binary_accuracy: 0.9629
# Epoch 160/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0241 - binary_accuracy: 0.9917 - val_loss: 0.1303 - val_binary_accuracy: 0.9629
# Epoch 161/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0287 - binary_accuracy: 0.9890 - val_loss: 0.1113 - val_binary_accuracy: 0.9586
# Epoch 162/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0205 - binary_accuracy: 0.9926 - val_loss: 0.1507 - val_binary_accuracy: 0.9486
# Epoch 163/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0225 - binary_accuracy: 0.9898 - val_loss: 0.0887 - val_binary_accuracy: 0.9736
# Epoch 164/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0200 - binary_accuracy: 0.9925 - val_loss: 0.1194 - val_binary_accuracy: 0.9693
# Epoch 165/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0469 - binary_accuracy: 0.9843 - val_loss: 0.0997 - val_binary_accuracy: 0.9700
# Epoch 166/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0237 - binary_accuracy: 0.9922 - val_loss: 0.1084 - val_binary_accuracy: 0.9743
# Epoch 167/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0407 - binary_accuracy: 0.9854 - val_loss: 0.1381 - val_binary_accuracy: 0.9536
# Epoch 168/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0299 - binary_accuracy: 0.9895 - val_loss: 0.1190 - val_binary_accuracy: 0.9679
# Epoch 169/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0365 - binary_accuracy: 0.9892 - val_loss: 0.0911 - val_binary_accuracy: 0.9679
# Epoch 170/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0210 - binary_accuracy: 0.9925 - val_loss: 0.0881 - val_binary_accuracy: 0.9764
# Epoch 171/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0149 - binary_accuracy: 0.9937 - val_loss: 0.1119 - val_binary_accuracy: 0.9657
# Epoch 172/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0236 - binary_accuracy: 0.9916 - val_loss: 0.0866 - val_binary_accuracy: 0.9693
# Epoch 173/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0178 - binary_accuracy: 0.9922 - val_loss: 0.1107 - val_binary_accuracy: 0.9707
# Epoch 174/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0363 - binary_accuracy: 0.9872 - val_loss: 0.1108 - val_binary_accuracy: 0.9650
# Epoch 175/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0258 - binary_accuracy: 0.9902 - val_loss: 0.1056 - val_binary_accuracy: 0.9657
# Epoch 176/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0229 - binary_accuracy: 0.9901 - val_loss: 0.1547 - val_binary_accuracy: 0.9607
# Epoch 177/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0433 - binary_accuracy: 0.9845 - val_loss: 0.1454 - val_binary_accuracy: 0.9679
# Epoch 178/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0282 - binary_accuracy: 0.9888 - val_loss: 0.1274 - val_binary_accuracy: 0.9614
# Epoch 179/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0351 - binary_accuracy: 0.9880 - val_loss: 0.1577 - val_binary_accuracy: 0.9657
# Epoch 180/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0398 - binary_accuracy: 0.9855 - val_loss: 0.1072 - val_binary_accuracy: 0.9671
# Epoch 181/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0247 - binary_accuracy: 0.9895 - val_loss: 0.1253 - val_binary_accuracy: 0.9664
# Epoch 182/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0357 - binary_accuracy: 0.9871 - val_loss: 0.1247 - val_binary_accuracy: 0.9679
# Epoch 183/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0328 - binary_accuracy: 0.9875 - val_loss: 0.1155 - val_binary_accuracy: 0.9679
# Epoch 184/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0306 - binary_accuracy: 0.9879 - val_loss: 0.1032 - val_binary_accuracy: 0.9686
# Epoch 185/500
# 79/79 [==============================] - 3s 38ms/step - loss: 0.0316 - binary_accuracy: 0.9900 - val_loss: 0.1104 - val_binary_accuracy: 0.9686
# Epoch 186/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0356 - binary_accuracy: 0.9869 - val_loss: 0.0949 - val_binary_accuracy: 0.9686
# Epoch 187/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0259 - binary_accuracy: 0.9917 - val_loss: 0.1092 - val_binary_accuracy: 0.9657
# Epoch 188/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0205 - binary_accuracy: 0.9906 - val_loss: 0.1339 - val_binary_accuracy: 0.9600
# Epoch 189/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0374 - binary_accuracy: 0.9888 - val_loss: 0.1347 - val_binary_accuracy: 0.9629
# Epoch 190/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0610 - binary_accuracy: 0.9851 - val_loss: 0.1013 - val_binary_accuracy: 0.9693
# Epoch 191/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0200 - binary_accuracy: 0.9915 - val_loss: 0.1292 - val_binary_accuracy: 0.9629
# Epoch 192/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0380 - binary_accuracy: 0.9867 - val_loss: 0.1068 - val_binary_accuracy: 0.9679
# Epoch 193/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0208 - binary_accuracy: 0.9911 - val_loss: 0.0872 - val_binary_accuracy: 0.9714
# Epoch 194/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0258 - binary_accuracy: 0.9909 - val_loss: 0.1502 - val_binary_accuracy: 0.9664
# Epoch 195/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0229 - binary_accuracy: 0.9923 - val_loss: 0.0976 - val_binary_accuracy: 0.9714
# Epoch 196/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0256 - binary_accuracy: 0.9910 - val_loss: 0.1080 - val_binary_accuracy: 0.9664
# Epoch 197/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0143 - binary_accuracy: 0.9931 - val_loss: 0.1223 - val_binary_accuracy: 0.9643
# Epoch 198/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0139 - binary_accuracy: 0.9947 - val_loss: 0.1277 - val_binary_accuracy: 0.9686
# Epoch 199/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0259 - binary_accuracy: 0.9901 - val_loss: 0.1137 - val_binary_accuracy: 0.9750
# Epoch 200/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0323 - binary_accuracy: 0.9854 - val_loss: 0.1271 - val_binary_accuracy: 0.9643
# Epoch 201/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0192 - binary_accuracy: 0.9934 - val_loss: 0.1348 - val_binary_accuracy: 0.9600
# Epoch 202/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0348 - binary_accuracy: 0.9892 - val_loss: 0.1600 - val_binary_accuracy: 0.9521
# Epoch 203/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0284 - binary_accuracy: 0.9882 - val_loss: 0.0972 - val_binary_accuracy: 0.9686
# Epoch 204/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0141 - binary_accuracy: 0.9940 - val_loss: 0.1106 - val_binary_accuracy: 0.9700
# Epoch 205/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0348 - binary_accuracy: 0.9886 - val_loss: 0.0969 - val_binary_accuracy: 0.9729
# Epoch 206/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0264 - binary_accuracy: 0.9905 - val_loss: 0.1116 - val_binary_accuracy: 0.9729
# Epoch 207/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0358 - binary_accuracy: 0.9876 - val_loss: 0.0912 - val_binary_accuracy: 0.9693
# Epoch 208/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0284 - binary_accuracy: 0.9885 - val_loss: 0.1373 - val_binary_accuracy: 0.9664
# Epoch 209/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0293 - binary_accuracy: 0.9883 - val_loss: 0.0949 - val_binary_accuracy: 0.9700
# Epoch 210/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0293 - binary_accuracy: 0.9886 - val_loss: 0.1162 - val_binary_accuracy: 0.9721
# Epoch 211/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0338 - binary_accuracy: 0.9883 - val_loss: 0.0915 - val_binary_accuracy: 0.9700
# Epoch 212/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0125 - binary_accuracy: 0.9939 - val_loss: 0.1053 - val_binary_accuracy: 0.9686
# Epoch 213/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0181 - binary_accuracy: 0.9929 - val_loss: 0.1057 - val_binary_accuracy: 0.9721
# Epoch 214/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0155 - binary_accuracy: 0.9933 - val_loss: 0.1046 - val_binary_accuracy: 0.9736
# Epoch 215/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0398 - binary_accuracy: 0.9874 - val_loss: 0.1471 - val_binary_accuracy: 0.9593
# Epoch 216/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0413 - binary_accuracy: 0.9859 - val_loss: 0.1109 - val_binary_accuracy: 0.9629
# Epoch 217/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0344 - binary_accuracy: 0.9869 - val_loss: 0.1005 - val_binary_accuracy: 0.9679
# Epoch 218/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0331 - binary_accuracy: 0.9884 - val_loss: 0.1065 - val_binary_accuracy: 0.9664
# Epoch 219/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0264 - binary_accuracy: 0.9881 - val_loss: 0.1213 - val_binary_accuracy: 0.9657
# Epoch 220/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0362 - binary_accuracy: 0.9886 - val_loss: 0.1082 - val_binary_accuracy: 0.9714
# Epoch 221/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0213 - binary_accuracy: 0.9911 - val_loss: 0.1175 - val_binary_accuracy: 0.9714
# Epoch 222/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0185 - binary_accuracy: 0.9921 - val_loss: 0.1125 - val_binary_accuracy: 0.9686
# Epoch 223/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0223 - binary_accuracy: 0.9910 - val_loss: 0.1137 - val_binary_accuracy: 0.9700
# Epoch 224/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0308 - binary_accuracy: 0.9867 - val_loss: 0.1337 - val_binary_accuracy: 0.9621
# Epoch 225/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0309 - binary_accuracy: 0.9863 - val_loss: 0.0919 - val_binary_accuracy: 0.9693
# Epoch 226/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0457 - binary_accuracy: 0.9849 - val_loss: 0.0900 - val_binary_accuracy: 0.9743
# Epoch 227/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0188 - binary_accuracy: 0.9927 - val_loss: 0.1193 - val_binary_accuracy: 0.9579
# Epoch 228/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0249 - binary_accuracy: 0.9915 - val_loss: 0.1215 - val_binary_accuracy: 0.9614
# Epoch 229/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0325 - binary_accuracy: 0.9882 - val_loss: 0.0801 - val_binary_accuracy: 0.9679
# Epoch 230/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0372 - binary_accuracy: 0.9866 - val_loss: 0.0967 - val_binary_accuracy: 0.9707
# Epoch 231/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0136 - binary_accuracy: 0.9944 - val_loss: 0.0877 - val_binary_accuracy: 0.9750
# Epoch 232/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0320 - binary_accuracy: 0.9913 - val_loss: 0.1544 - val_binary_accuracy: 0.9650
# Epoch 233/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0234 - binary_accuracy: 0.9923 - val_loss: 0.1226 - val_binary_accuracy: 0.9643
# Epoch 234/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0210 - binary_accuracy: 0.9916 - val_loss: 0.1593 - val_binary_accuracy: 0.9507
# Epoch 235/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0189 - binary_accuracy: 0.9925 - val_loss: 0.1458 - val_binary_accuracy: 0.9643
# Epoch 236/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0195 - binary_accuracy: 0.9922 - val_loss: 0.0922 - val_binary_accuracy: 0.9743
# Epoch 237/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0191 - binary_accuracy: 0.9943 - val_loss: 0.1260 - val_binary_accuracy: 0.9636
# Epoch 238/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0267 - binary_accuracy: 0.9895 - val_loss: 0.1145 - val_binary_accuracy: 0.9700
# Epoch 239/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0354 - binary_accuracy: 0.9899 - val_loss: 0.1503 - val_binary_accuracy: 0.9571
# Epoch 240/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0445 - binary_accuracy: 0.9839 - val_loss: 0.1200 - val_binary_accuracy: 0.9679
# Epoch 241/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0378 - binary_accuracy: 0.9872 - val_loss: 0.1114 - val_binary_accuracy: 0.9657
# Epoch 242/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0184 - binary_accuracy: 0.9930 - val_loss: 0.0976 - val_binary_accuracy: 0.9664
# Epoch 243/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0311 - binary_accuracy: 0.9881 - val_loss: 0.1059 - val_binary_accuracy: 0.9693
# Epoch 244/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0297 - binary_accuracy: 0.9890 - val_loss: 0.1130 - val_binary_accuracy: 0.9629
# Epoch 245/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0352 - binary_accuracy: 0.9874 - val_loss: 0.1135 - val_binary_accuracy: 0.9729
# Epoch 246/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0164 - binary_accuracy: 0.9934 - val_loss: 0.1368 - val_binary_accuracy: 0.9636
# Epoch 247/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0237 - binary_accuracy: 0.9907 - val_loss: 0.0991 - val_binary_accuracy: 0.9700
# Epoch 248/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0188 - binary_accuracy: 0.9921 - val_loss: 0.0846 - val_binary_accuracy: 0.9750
# Epoch 249/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0250 - binary_accuracy: 0.9910 - val_loss: 0.1275 - val_binary_accuracy: 0.9593
# Epoch 250/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0310 - binary_accuracy: 0.9877 - val_loss: 0.0999 - val_binary_accuracy: 0.9700
# Epoch 251/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0178 - binary_accuracy: 0.9918 - val_loss: 0.1196 - val_binary_accuracy: 0.9664
# Epoch 252/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0120 - binary_accuracy: 0.9954 - val_loss: 0.1800 - val_binary_accuracy: 0.9579
# Epoch 253/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0240 - binary_accuracy: 0.9917 - val_loss: 0.1398 - val_binary_accuracy: 0.9643
# Epoch 254/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0194 - binary_accuracy: 0.9931 - val_loss: 0.1700 - val_binary_accuracy: 0.9486
# Epoch 255/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0213 - binary_accuracy: 0.9923 - val_loss: 0.1011 - val_binary_accuracy: 0.9629
# Epoch 256/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0232 - binary_accuracy: 0.9909 - val_loss: 0.1225 - val_binary_accuracy: 0.9664
# Epoch 257/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0285 - binary_accuracy: 0.9895 - val_loss: 0.0996 - val_binary_accuracy: 0.9686
# Epoch 258/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0146 - binary_accuracy: 0.9944 - val_loss: 0.1729 - val_binary_accuracy: 0.9607
# Epoch 259/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0393 - binary_accuracy: 0.9874 - val_loss: 0.1263 - val_binary_accuracy: 0.9643
# Epoch 260/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0177 - binary_accuracy: 0.9919 - val_loss: 0.0977 - val_binary_accuracy: 0.9650
# Epoch 261/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0250 - binary_accuracy: 0.9905 - val_loss: 0.1161 - val_binary_accuracy: 0.9679
# Epoch 262/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0361 - binary_accuracy: 0.9876 - val_loss: 0.1048 - val_binary_accuracy: 0.9729
# Epoch 263/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0192 - binary_accuracy: 0.9922 - val_loss: 0.1051 - val_binary_accuracy: 0.9736
# Epoch 264/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0160 - binary_accuracy: 0.9928 - val_loss: 0.1157 - val_binary_accuracy: 0.9636
# Epoch 265/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0400 - binary_accuracy: 0.9872 - val_loss: 0.1145 - val_binary_accuracy: 0.9700
# Epoch 266/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0277 - binary_accuracy: 0.9897 - val_loss: 0.1258 - val_binary_accuracy: 0.9664
# Epoch 267/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0352 - binary_accuracy: 0.9875 - val_loss: 0.0979 - val_binary_accuracy: 0.9757
# Epoch 268/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0226 - binary_accuracy: 0.9919 - val_loss: 0.1282 - val_binary_accuracy: 0.9650
# Epoch 269/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0168 - binary_accuracy: 0.9947 - val_loss: 0.1198 - val_binary_accuracy: 0.9743
# Epoch 270/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0116 - binary_accuracy: 0.9950 - val_loss: 0.0981 - val_binary_accuracy: 0.9714
# Epoch 271/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0360 - binary_accuracy: 0.9880 - val_loss: 0.1233 - val_binary_accuracy: 0.9671
# Epoch 272/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0280 - binary_accuracy: 0.9899 - val_loss: 0.0884 - val_binary_accuracy: 0.9700
# Epoch 273/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0199 - binary_accuracy: 0.9916 - val_loss: 0.1122 - val_binary_accuracy: 0.9707
# Epoch 274/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0320 - binary_accuracy: 0.9887 - val_loss: 0.1234 - val_binary_accuracy: 0.9679
# Epoch 275/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0549 - binary_accuracy: 0.9827 - val_loss: 0.0891 - val_binary_accuracy: 0.9714
# Epoch 276/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0264 - binary_accuracy: 0.9888 - val_loss: 0.1121 - val_binary_accuracy: 0.9671
# Epoch 277/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0320 - binary_accuracy: 0.9888 - val_loss: 0.0872 - val_binary_accuracy: 0.9750
# Epoch 278/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0173 - binary_accuracy: 0.9920 - val_loss: 0.1204 - val_binary_accuracy: 0.9664
# Epoch 279/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0224 - binary_accuracy: 0.9902 - val_loss: 0.1104 - val_binary_accuracy: 0.9743
# Epoch 280/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0223 - binary_accuracy: 0.9916 - val_loss: 0.1255 - val_binary_accuracy: 0.9679
# Epoch 281/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0153 - binary_accuracy: 0.9937 - val_loss: 0.1194 - val_binary_accuracy: 0.9657
# Epoch 282/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0132 - binary_accuracy: 0.9939 - val_loss: 0.1208 - val_binary_accuracy: 0.9700
# Epoch 283/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0211 - binary_accuracy: 0.9926 - val_loss: 0.1394 - val_binary_accuracy: 0.9579
# Epoch 284/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0167 - binary_accuracy: 0.9939 - val_loss: 0.1470 - val_binary_accuracy: 0.9686
# Epoch 285/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0163 - binary_accuracy: 0.9932 - val_loss: 0.1349 - val_binary_accuracy: 0.9657
# Epoch 286/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0225 - binary_accuracy: 0.9925 - val_loss: 0.1315 - val_binary_accuracy: 0.9650
# Epoch 287/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0188 - binary_accuracy: 0.9917 - val_loss: 0.1471 - val_binary_accuracy: 0.9693
# Epoch 288/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0322 - binary_accuracy: 0.9877 - val_loss: 0.1666 - val_binary_accuracy: 0.9543
# Epoch 289/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0212 - binary_accuracy: 0.9910 - val_loss: 0.1537 - val_binary_accuracy: 0.9579
# Epoch 290/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0274 - binary_accuracy: 0.9897 - val_loss: 0.1925 - val_binary_accuracy: 0.9579
# Epoch 291/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0476 - binary_accuracy: 0.9875 - val_loss: 0.1785 - val_binary_accuracy: 0.9571
# Epoch 292/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0239 - binary_accuracy: 0.9916 - val_loss: 0.1062 - val_binary_accuracy: 0.9707
# Epoch 293/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0362 - binary_accuracy: 0.9875 - val_loss: 0.1126 - val_binary_accuracy: 0.9693
# Epoch 294/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0289 - binary_accuracy: 0.9896 - val_loss: 0.1090 - val_binary_accuracy: 0.9700
# Epoch 295/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0322 - binary_accuracy: 0.9882 - val_loss: 0.1146 - val_binary_accuracy: 0.9636
# Epoch 296/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0190 - binary_accuracy: 0.9921 - val_loss: 0.1314 - val_binary_accuracy: 0.9707
# Epoch 297/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0212 - binary_accuracy: 0.9916 - val_loss: 0.1321 - val_binary_accuracy: 0.9714
# Epoch 298/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0284 - binary_accuracy: 0.9897 - val_loss: 0.1422 - val_binary_accuracy: 0.9657
# Epoch 299/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0208 - binary_accuracy: 0.9921 - val_loss: 0.1344 - val_binary_accuracy: 0.9693
# Epoch 300/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0143 - binary_accuracy: 0.9944 - val_loss: 0.1429 - val_binary_accuracy: 0.9693
# Epoch 301/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0200 - binary_accuracy: 0.9931 - val_loss: 0.1328 - val_binary_accuracy: 0.9679
# Epoch 302/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0277 - binary_accuracy: 0.9904 - val_loss: 0.1300 - val_binary_accuracy: 0.9679
# Epoch 303/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0266 - binary_accuracy: 0.9914 - val_loss: 0.1147 - val_binary_accuracy: 0.9714
# Epoch 304/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0215 - binary_accuracy: 0.9921 - val_loss: 0.1268 - val_binary_accuracy: 0.9664
# Epoch 305/500
# ...
# Epoch 401/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0253 - binary_accuracy: 0.9896 - val_loss: 0.1186 - val_binary_accuracy: 0.9729
# Epoch 402/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0130 - binary_accuracy: 0.9946 - val_loss: 0.1225 - val_binary_accuracy: 0.9707
# Epoch 403/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0194 - binary_accuracy: 0.9925 - val_loss: 0.1082 - val_binary_accuracy: 0.9643
# Epoch 404/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0217 - binary_accuracy: 0.9916 - val_loss: 0.1515 - val_binary_accuracy: 0.9629
# Epoch 405/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0393 - binary_accuracy: 0.9865 - val_loss: 0.1405 - val_binary_accuracy: 0.9643
# Epoch 406/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0439 - binary_accuracy: 0.9863 - val_loss: 0.1549 - val_binary_accuracy: 0.9643
# Epoch 407/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0217 - binary_accuracy: 0.9915 - val_loss: 0.1217 - val_binary_accuracy: 0.9714
# Epoch 408/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0279 - binary_accuracy: 0.9917 - val_loss: 0.1137 - val_binary_accuracy: 0.9714
# Epoch 409/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0182 - binary_accuracy: 0.9929 - val_loss: 0.1370 - val_binary_accuracy: 0.9686
# Epoch 410/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0228 - binary_accuracy: 0.9928 - val_loss: 0.1293 - val_binary_accuracy: 0.9686
# Epoch 411/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0269 - binary_accuracy: 0.9885 - val_loss: 0.1763 - val_binary_accuracy: 0.9671
# Epoch 412/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0323 - binary_accuracy: 0.9870 - val_loss: 0.1215 - val_binary_accuracy: 0.9714
# Epoch 413/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0270 - binary_accuracy: 0.9912 - val_loss: 0.1369 - val_binary_accuracy: 0.9657
# Epoch 414/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0209 - binary_accuracy: 0.9912 - val_loss: 0.1014 - val_binary_accuracy: 0.9721
# Epoch 415/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0254 - binary_accuracy: 0.9899 - val_loss: 0.1410 - val_binary_accuracy: 0.9693
# Epoch 416/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0192 - binary_accuracy: 0.9926 - val_loss: 0.1200 - val_binary_accuracy: 0.9679
# Epoch 417/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0140 - binary_accuracy: 0.9931 - val_loss: 0.1081 - val_binary_accuracy: 0.9721
# Epoch 418/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0312 - binary_accuracy: 0.9898 - val_loss: 0.1073 - val_binary_accuracy: 0.9721
# Epoch 419/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0214 - binary_accuracy: 0.9930 - val_loss: 0.1276 - val_binary_accuracy: 0.9750
# Epoch 420/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0153 - binary_accuracy: 0.9926 - val_loss: 0.1652 - val_binary_accuracy: 0.9571
# Epoch 421/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0183 - binary_accuracy: 0.9929 - val_loss: 0.1297 - val_binary_accuracy: 0.9707
# Epoch 422/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0193 - binary_accuracy: 0.9910 - val_loss: 0.1335 - val_binary_accuracy: 0.9614
# Epoch 423/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0198 - binary_accuracy: 0.9927 - val_loss: 0.1318 - val_binary_accuracy: 0.9707
# Epoch 424/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0156 - binary_accuracy: 0.9937 - val_loss: 0.1184 - val_binary_accuracy: 0.9643
# Epoch 425/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0192 - binary_accuracy: 0.9944 - val_loss: 0.1511 - val_binary_accuracy: 0.9686
# Epoch 426/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0215 - binary_accuracy: 0.9915 - val_loss: 0.0943 - val_binary_accuracy: 0.9679
# Epoch 427/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0137 - binary_accuracy: 0.9932 - val_loss: 0.1300 - val_binary_accuracy: 0.9657
# Epoch 428/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0153 - binary_accuracy: 0.9951 - val_loss: 0.1619 - val_binary_accuracy: 0.9593
# Epoch 429/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0298 - binary_accuracy: 0.9889 - val_loss: 0.0951 - val_binary_accuracy: 0.9700
# Epoch 430/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0283 - binary_accuracy: 0.9899 - val_loss: 0.1619 - val_binary_accuracy: 0.9650
# Epoch 431/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0175 - binary_accuracy: 0.9932 - val_loss: 0.1488 - val_binary_accuracy: 0.9664
# Epoch 432/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0287 - binary_accuracy: 0.9904 - val_loss: 0.1234 - val_binary_accuracy: 0.9564
# Epoch 433/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0359 - binary_accuracy: 0.9887 - val_loss: 0.0931 - val_binary_accuracy: 0.9736
# Epoch 434/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0259 - binary_accuracy: 0.9908 - val_loss: 0.1200 - val_binary_accuracy: 0.9571
# Epoch 435/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0351 - binary_accuracy: 0.9881 - val_loss: 0.1390 - val_binary_accuracy: 0.9643
# Epoch 436/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0235 - binary_accuracy: 0.9919 - val_loss: 0.1679 - val_binary_accuracy: 0.9586
# Epoch 437/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0249 - binary_accuracy: 0.9927 - val_loss: 0.1422 - val_binary_accuracy: 0.9636
# Epoch 438/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0125 - binary_accuracy: 0.9943 - val_loss: 0.1124 - val_binary_accuracy: 0.9679
# Epoch 439/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0137 - binary_accuracy: 0.9947 - val_loss: 0.1449 - val_binary_accuracy: 0.9650
# Epoch 440/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0120 - binary_accuracy: 0.9948 - val_loss: 0.1031 - val_binary_accuracy: 0.9679
# Epoch 441/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0241 - binary_accuracy: 0.9912 - val_loss: 0.1849 - val_binary_accuracy: 0.9700
# Epoch 442/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0236 - binary_accuracy: 0.9923 - val_loss: 0.1255 - val_binary_accuracy: 0.9643
# Epoch 443/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0339 - binary_accuracy: 0.9887 - val_loss: 0.1214 - val_binary_accuracy: 0.9621
# Epoch 444/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0312 - binary_accuracy: 0.9887 - val_loss: 0.1184 - val_binary_accuracy: 0.9636
# Epoch 445/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0259 - binary_accuracy: 0.9922 - val_loss: 0.0895 - val_binary_accuracy: 0.9693
# Epoch 446/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0278 - binary_accuracy: 0.9892 - val_loss: 0.1156 - val_binary_accuracy: 0.9729
# Epoch 447/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0385 - binary_accuracy: 0.9892 - val_loss: 0.1201 - val_binary_accuracy: 0.9671
# Epoch 448/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0139 - binary_accuracy: 0.9941 - val_loss: 0.1038 - val_binary_accuracy: 0.9679
# Epoch 449/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0224 - binary_accuracy: 0.9911 - val_loss: 0.1314 - val_binary_accuracy: 0.9686
# Epoch 450/500
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0125 - binary_accuracy: 0.9950 - val_loss: 0.1261 - val_binary_accuracy: 0.9714
# Epoch 451/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0102 - binary_accuracy: 0.9956 - val_loss: 0.1216 - val_binary_accuracy: 0.9671
# Epoch 452/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0120 - binary_accuracy: 0.9943 - val_loss: 0.1396 - val_binary_accuracy: 0.9614
# Epoch 453/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0181 - binary_accuracy: 0.9946 - val_loss: 0.1223 - val_binary_accuracy: 0.9593
# Epoch 454/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0315 - binary_accuracy: 0.9877 - val_loss: 0.1334 - val_binary_accuracy: 0.9564
# Epoch 455/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0419 - binary_accuracy: 0.9869 - val_loss: 0.1970 - val_binary_accuracy: 0.9450
# Epoch 456/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0243 - binary_accuracy: 0.9910 - val_loss: 0.1296 - val_binary_accuracy: 0.9636
# Epoch 457/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0172 - binary_accuracy: 0.9925 - val_loss: 0.1221 - val_binary_accuracy: 0.9607
# Epoch 458/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0321 - binary_accuracy: 0.9866 - val_loss: 0.1433 - val_binary_accuracy: 0.9700
# Epoch 459/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0192 - binary_accuracy: 0.9917 - val_loss: 0.1248 - val_binary_accuracy: 0.9636
# Epoch 460/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0233 - binary_accuracy: 0.9901 - val_loss: 0.1176 - val_binary_accuracy: 0.9686
# Epoch 461/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0277 - binary_accuracy: 0.9904 - val_loss: 0.1605 - val_binary_accuracy: 0.9636
# Epoch 462/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0153 - binary_accuracy: 0.9937 - val_loss: 0.1178 - val_binary_accuracy: 0.9693
# Epoch 463/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0260 - binary_accuracy: 0.9916 - val_loss: 0.1692 - val_binary_accuracy: 0.9686
# Epoch 464/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0117 - binary_accuracy: 0.9957 - val_loss: 0.1642 - val_binary_accuracy: 0.9636
# Epoch 465/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0184 - binary_accuracy: 0.9939 - val_loss: 0.1413 - val_binary_accuracy: 0.9686
# Epoch 466/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0129 - binary_accuracy: 0.9945 - val_loss: 0.1124 - val_binary_accuracy: 0.9671
# Epoch 467/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0145 - binary_accuracy: 0.9943 - val_loss: 0.1341 - val_binary_accuracy: 0.9657
# Epoch 468/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0200 - binary_accuracy: 0.9941 - val_loss: 0.1341 - val_binary_accuracy: 0.9614
# Epoch 469/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0177 - binary_accuracy: 0.9920 - val_loss: 0.1045 - val_binary_accuracy: 0.9686
# Epoch 470/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0143 - binary_accuracy: 0.9932 - val_loss: 0.1608 - val_binary_accuracy: 0.9629
# Epoch 471/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0244 - binary_accuracy: 0.9914 - val_loss: 0.1297 - val_binary_accuracy: 0.9643
# Epoch 472/500
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0188 - binary_accuracy: 0.9945 - val_loss: 0.1232 - val_binary_accuracy: 0.9679
# Epoch 473/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0198 - binary_accuracy: 0.9904 - val_loss: 0.1357 - val_binary_accuracy: 0.9671
# Epoch 474/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0281 - binary_accuracy: 0.9905 - val_loss: 0.1369 - val_binary_accuracy: 0.9593
# Epoch 475/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0473 - binary_accuracy: 0.9846 - val_loss: 0.1227 - val_binary_accuracy: 0.9671
# Epoch 476/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0220 - binary_accuracy: 0.9912 - val_loss: 0.1076 - val_binary_accuracy: 0.9686
# Epoch 477/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0452 - binary_accuracy: 0.9855 - val_loss: 0.1024 - val_binary_accuracy: 0.9693
# Epoch 478/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0247 - binary_accuracy: 0.9901 - val_loss: 0.0913 - val_binary_accuracy: 0.9693
# Epoch 479/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0350 - binary_accuracy: 0.9905 - val_loss: 0.1120 - val_binary_accuracy: 0.9700
# Epoch 480/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0241 - binary_accuracy: 0.9919 - val_loss: 0.1266 - val_binary_accuracy: 0.9664
# Epoch 481/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0198 - binary_accuracy: 0.9921 - val_loss: 0.1486 - val_binary_accuracy: 0.9700
# Epoch 482/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0120 - binary_accuracy: 0.9948 - val_loss: 0.1141 - val_binary_accuracy: 0.9693
# Epoch 483/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0265 - binary_accuracy: 0.9914 - val_loss: 0.1112 - val_binary_accuracy: 0.9693
# Epoch 484/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0158 - binary_accuracy: 0.9929 - val_loss: 0.1221 - val_binary_accuracy: 0.9679
# Epoch 485/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0241 - binary_accuracy: 0.9923 - val_loss: 0.1064 - val_binary_accuracy: 0.9679
# Epoch 486/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0164 - binary_accuracy: 0.9923 - val_loss: 0.1088 - val_binary_accuracy: 0.9707
# Epoch 487/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0341 - binary_accuracy: 0.9882 - val_loss: 0.1042 - val_binary_accuracy: 0.9664
# Epoch 488/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0730 - binary_accuracy: 0.9812 - val_loss: 0.1264 - val_binary_accuracy: 0.9593
# Epoch 489/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0292 - binary_accuracy: 0.9864 - val_loss: 0.0877 - val_binary_accuracy: 0.9750
# Epoch 490/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0116 - binary_accuracy: 0.9946 - val_loss: 0.1014 - val_binary_accuracy: 0.9693
# Epoch 491/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0137 - binary_accuracy: 0.9950 - val_loss: 0.0966 - val_binary_accuracy: 0.9714
# Epoch 492/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0131 - binary_accuracy: 0.9947 - val_loss: 0.1525 - val_binary_accuracy: 0.9664
# Epoch 493/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0137 - binary_accuracy: 0.9958 - val_loss: 0.1163 - val_binary_accuracy: 0.9750
# Epoch 494/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0125 - binary_accuracy: 0.9961 - val_loss: 0.0915 - val_binary_accuracy: 0.9771
# Epoch 495/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0136 - binary_accuracy: 0.9945 - val_loss: 0.1214 - val_binary_accuracy: 0.9664
# Epoch 496/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0262 - binary_accuracy: 0.9917 - val_loss: 0.1079 - val_binary_accuracy: 0.9721
# Epoch 497/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0219 - binary_accuracy: 0.9911 - val_loss: 0.1233 - val_binary_accuracy: 0.9700
# Epoch 498/500
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0217 - binary_accuracy: 0.9905 - val_loss: 0.1310 - val_binary_accuracy: 0.9721
# Epoch 499/500
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0208 - binary_accuracy: 0.9921 - val_loss: 0.1066 - val_binary_accuracy: 0.9693
# Epoch 500/500
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0247 - binary_accuracy: 0.9896 - val_loss: 0.1203 - val_binary_accuracy: 0.9686
# 19/19 [==============================] - 1s 22ms/step - loss: 0.1145 - binary_accuracy: 0.9644
# Test accuracy: 96.44%

# %%
preds =tf.nn.sigmoid(preds)

# %%
n_preds =preds.shape[0]
tclass = (np.equal(np.argmax(test_labels[:, :2], axis=1), np.argmax(preds[:, :2], axis=1))).astype(int)
tumor_class_acc = tclass.mean()


# ttype = (np.equal(np.argmax(test_labels, axis=1), np.argmax(preds, axis=1))).astype(int)

ttype = (np.equal(np.argmax(test_labels[:, 2:], axis=1), np.argmax(preds[:, 2:], axis=1))).astype(int)
tumor_type_acc =ttype.mean()
global_acc  =(tclass *ttype).mean()

# %%
print(f'Tunor type accuracy:{tumor_type_acc}')
print(f'Tunor class(benign/ malignant) accuracy:{tumor_class_acc}')
print(f'Tunor accuracy:{global_acc}')
# Out:
# Tunor type accuracy:0.8564273789649416
# Tunor class(benign/ malignant) accuracy:0.9632721202003339
# Tunor accuracy:0.8497495826377296

# %%
# np.argmax(test_labels[:, :2], axis=1)

# %%
m = tf.keras.metrics.BinaryAccuracy()
m.update_state(y_test[:,:2], preds[:,:2])
m.result().numpy()
# Out:
# 0.9632721

# %%
m = tf.keras.metrics.CategoricalAccuracy()
m.update_state(y_test[:,2:], preds[:,2:])
m.result().numpy()
# Out:
# 0.8564274

# %%
# metric = tfa.metrics.F1Score(num_classes=2, threshold=0.5)
# metric.update_state(y_test[:,:2], preds[:,:2])
# result = metric.result()
# result.numpy()

# %%
m = tf.keras.metrics.AUC(num_thresholds=3)
m.update_state(y_test[:,:2], preds[:,:2])

m.result().numpy()
# Out:
# 0.9632721

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt



def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm = confusion_matrix(np.argmax(test_labels[:, :2], axis=1), np.argmax(preds[:, :2], axis=1))
plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, np.arange(2))
# Out:
# Confusion matrix, without normalization
# [[196   8]
#  [ 14 381]]

# %%
# print(y_test[:4,2:])

# %%
# preds[:4,2:]

# %%
# tclass = (np.equal(np.argmax(test_labels[:4, 2:], axis=1), np.argmax(preds[:4, 2:], axis=1))).astype(int)
# tumor_class_acc = tclass.mean()
# tumor_class_acc

# %%
# m = tf.keras.metrics.CategoricalAccuracy()
# m.update_state([[0, 0, 1], [0, 1, 0]], [[0.1, 0.9, 0.8],
#                  [0.05, 0.95, 0]])
# m.result().numpy()

# %%
# m.reset_states()
# m.update_state([[0, 0, 1], [0, 1, 0]], [[0.1, 0.9, 0.8],
#                  [0.05, 0.95, 0]],               sample_weight=[0.7, 0.3])
# m.result().numpy()
